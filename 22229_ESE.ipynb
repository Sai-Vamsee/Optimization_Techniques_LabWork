# %% [markdown]
# ## MDSC – 103(P)-ESE
#
# ### Redg.no:22229

# %% [markdown]
# ### 1. Wilson Problem:

# %% [markdown]
# x1 = number of dozens of baseballs manufactured daily
#
# x2 = number of dozens of softballs manufactured daily

# %% [markdown]
# ### (a)

# %% [markdown]
#   Max
#             $$ z = 7x1+10x2 $$
#   subject to :
#             $$ 5x1+6x2<=3600 $$
#             $$ 1x1+2x2<=960 $$
#             $$ x1<=500 $$
#             $$ x2<=500 $$

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### (b)

# %% [markdown]
# The number of dozens of base balls can be increased from 500 to 500+(1E+30) and can be decreased from 500 to 498
#
# Therefore the allowable range of manufacture of baseballs per day is (498,500+(1E+30))
#
# The number of dozens of soft balls can be increased from 500 to 504 and can be decreased from 500 to 490
#
# Therefore the allowable range of manufacture of softballs per day is (490,504)

# %% [markdown]
# ### (c)

# %% [markdown]
# The availability of cowhide sheet can be increased to 3860 sq.feet and can be decreased to 3540
#
# So the range for the avilability of cowhidesheet is from (3860,3540)
#
# The availability of time per day can be increased to 960+(1E+30) minutes and can be decreased to 708
#
# The availability of time per day has the range of (960+(1E+30),708)

# %% [markdown]
# ### (d)

# %%
c = [7, 10]
A = [[5, 6], [1, 2],[1,0],[0,1]]
b = [3600, 960,500,500]

from scipy.optimize import linprog
res = linprog(c, A_ub=A, b_ub=b)

# %%
print(res)
# Out:
#      con: array([], dtype=float64)
#      fun: 8.63487845852155e-12
#  message: 'Optimization terminated successfully.'
#      nit: 7
#    slack: array([3600.,  960.,  500.,  500.])
#   status: 0
#  success: True
#        x: array([4.92815956e-13, 5.18516677e-13])

# %% [markdown]
# ### 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.optimize import root

def fun(x,y):
    a = lambda z: 4*x + 6*y - 2*(x**2) - 2*x*y - 2*(y**2)
    return a
